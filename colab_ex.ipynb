# %% [markdown]
# # Import script file

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('stock_streamlit.py', 'wb').write(src)
import stock_streamlit
# Out:
#      <input type="file" id="files-13a37293-331a-478e-ba12-60a5020b92f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13a37293-331a-478e-ba12-60a5020b92f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stock_streamlit.py to stock_streamlit.py

# %% [markdown]
# # Open files from your local file system

# %% [markdown]
# * Upload files from your local file system

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a57511e6-8575-4eb9-9727-b36930c2c94b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a57511e6-8575-4eb9-9727-b36930c2c94b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-292f82be1b7a> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 uploaded = files.upload()
#       4
#       5 for fn in uploaded.keys():
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
#      65   files = _collections.defaultdict(_six.binary_type)
#      66   # Mapping from original filename to filename as saved locally.
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# * Download a file from the path

# %%
files.download('/content/sample_data/california_housing_train.csv')

# %%
# !ls

# %% [markdown]
# * Move a file to Google Drive

# %%
# !mv stock_streamlit.py ./drive/MyDrive/Colab_Notebooks

# %% [markdown]
# # Open files from GitHub

# %% [markdown]
# * Load files from GitHub

# %%
# Clone the entire repo.
# !git clone -l -s https://github.com/engineerto/streamlit.git cloned-repo
# %cd cloned-repo
# !ls

# %% [markdown]
# * Copy file to Google Drive

# %%
# !cp stock_streamlit.py /content/drive/MyDrive/Colab_Notebooks/stock_streamlit.py

# %% [markdown]
# * Change work directory

# %%
# %cd /content

# %%
# !ls

# %% [markdown]
# * Copy directory to Google Drive

# %%
# !cp -r cloned-repo /content/drive/MyDrive/Colab_Notebooks

# %% [markdown]
# # Use Streamlit from Colab

# %% [markdown]
# * #1 Using localtunnel

# %%
# !pip install streamlit

# %%
# !npm install localtunnel

# %%
# !streamlit run stock_streamlit.py &>/dev/nul&

# %%
# !npx localtunnel --port 8501

# %%
# !streamlit run stock_streamlit.py

# %% [markdown]
# * #2 Using ngrok

# %%
# !pip install streamlit -q

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -qq ngrok-stable-linux-amd64.zip

# %%
get_ipython().system_raw('./ngrok http 8501 &')

# %%
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    'import sys, json; print("Execute the next cell and the go to the following URL: " +json.load(sys.stdin)["tunnels"][0]["public_url"])'

# %% [markdown]
# * Run from work directory

# %%
# !streamlit run stock_streamlit.py

# %% [markdown]
# * Run from path

# %%
# !streamlit run ./drive/MyDrive/Colab_Notebooks/stock_streamlit.py

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/
# Out:
# /content/drive/MyDrive/Colab_Notebooks

# %%
# !ls
# Out:
# ai-ojt	 a.py	cloned-repo	readme.txt
# a.ipynb  a.txt	colab_ex.ipynb	stock_streamlit.py

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab_Notebooks/.git/

# %%
# !git config --global user.email "kweras95@gmail.com"
# !git config --global user.name "Taeo Kim"

# %%
# !git add colab_ex.ipynb

# %%
# !git commit -m "Colab commit1"
# Out:
# [master (root-commit) e6068c1] Colab commit1
#  1 file changed, 1 insertion(+)
#  create mode 100644 colab_ex.ipynb

# %%
# !git remote add origin https://engineerto:as138546@github.com/engineerto/streamlit.git

# %%
# !git push -u origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 7.95 KiB | 1.99 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'master' on GitHub by visiting:
# remote:      https://github.com/engineerto/streamlit/pull/new/master
# remote:
# To https://github.com/engineerto/streamlit.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git add "colab_ex.ipynb"

# %%
# !git commit -m "Colab Commit"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/engineerto/streamlit.git'
